# %% [markdown]
# **Zadanie 16 – Dziedziczenie wielopoziomowe: Zwierzęta** *(challenge)*
#
# Struktura: `Zwierze` (`nazwa`, `wiek`) → `Ssak(Zwierze)` (`typ_futra`) → `Pies(Ssak)` (`rasa`). Każda klasa ma `pokaz_info()` wyświetlającą wszystkie atrybuty. Stwórz obiekt `Pies` i wywołaj metodę.** Zadanie
# 18 – Pipeline
# z
# walidacją
# danych ** * (challenge) *
#
# Komponenty: `ValidatorZakresu(min,
#                               max)`, `ValidatorTypu(typ)`, `ValidatorBrakow`.Każdy validator zwraca `(True / False, komunikat)`.
#                               Pipeline agreguje wyniki walidacji.

# %%
class Zwierze:
    def __init__(self, nazwa, wiek):
        self.nazwa = nazwa
        self.wiek = wiek

    def pokaz_info(self):
        print(f"Nazwa: {self.nazwa}")
        print(f"Wiek: {self.wiek}")


class Ssak(Zwierze):
    def __init__(self, nazwa, wiek, typ_futra):
        super().__init__(nazwa, wiek)
        self.typ_futra = typ_futra

    def pokaz_info(self):
        super().pokaz_info()
        print(f"Typ futra: {self.typ_futra}")


class Pies(Ssak):
    def __init__(self, nazwa, wiek, typ_futra, rasa):
        super().__init__(nazwa, wiek, typ_futra)
        self.rasa = rasa

    def pokaz_info(self):
        super().pokaz_info()
        print(f"Rasa: {self.rasa}")


pies = Pies("Burek", 5, "gęste", "Owczarek niemiecki")
pies.pokaz_info()
# Out:
# Nazwa: Burek
# Wiek: 5
# Typ futra: gęste
# Rasa: Owczarek niemiecki

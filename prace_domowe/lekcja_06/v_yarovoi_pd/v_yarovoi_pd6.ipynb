# %% [markdown]
# ***Zadanie 3. Metryki modelu***
#
# Utwórz słownik metryki z kluczami accuracy , precision , recall , f1_score i wartościami
# odpowiednio 0.94 , 0.91 , 0.89 , 0.90 .\
# Następnie używając funkcji wbudowanych ( min , max , sum ,
# len , sorted ):\
# Wypisz najwyższą i najniższą wartość metryki.\
# Wypisz średnią metrykę z dokładnością do 3 miejsc po przecinku.\
# Wypisz klucze posortowane alfabetycznie ( sorted ).\
# Wypisz wartości posortowane rosnąco.

# %%
slownik = {'accuracy':0.94,'precision':0.91, 'recall':0.89,'f1_score':0.90}

dict_values = list(slownik.values())

maximum_value = max(dict_values)
minimum_value = min(dict_values)
average_value = sum(dict_values)/len(slownik)

dict_keys = list(slownik.keys())
dict_keys_sorted = sorted(dict_keys)
dict_values_sorted = sorted(dict_values)

answer = f'''Najwyższa wartość = {maximum_value}
Najniższa wartość = {minimum_value}
Średnia wartość = {average_value:.3f}
Klucze posortowane alfebytycznie = {dict_keys_sorted}
Wartości posortowane rosnąco = {dict_values_sorted}
'''

print(answer)
# Out:
# Najwyższa wartość = 0.94
# Najniższa wartość = 0.89
# Średnia wartość = 0.910
# Klucze posortowane alfebytycznie = ['accuracy', 'f1_score', 'precision', 'recall']
# Wartości posortowane rosnąco = [0.89, 0.9, 0.91, 0.94]

# %% [markdown]
# ***Zadanie 5. Operacje na dwóch zbiorach***
#
# Dane są dwa zbiory narzędzi używanych przez dwie grupy analityków:\
# grupa_a = {'python', 'pandas', 'numpy', 'sql', 'tableau'}\
# grupa_b = {'python', 'r', 'sql', 'ggplot2', 'dplyr'}\
# Używając zarówno operatorów ( | , & , - , ^ ), jak i odpowiadających im metod, wypisz:\
# Sumę zbiorów (wszystkie narzędzia).\
# Wspólne narzędzia (iloczyn).\
# Narzędzia tylko w grupie A (różnica grupa_a - grupa_b ).\
# Narzędzia tylko w jednej z grup (różnica symetryczna).\
# Czy zbiory są rozłączne? ( .isdisjoint() )

# %%
Grupa_A = {'python', 'pandas', 'numpy', 'sql', 'tableau'}
Grupa_B = {'python', 'r', 'sql', 'ggplot2', 'dplyr'}

Suma_zbiorow_1 = Grupa_A | Grupa_B
Suma_zbiorow_2 = Grupa_A.union(Grupa_B)

Wspolne_narzedzia_1 = Grupa_A & Grupa_B
Wspolne_narzedzia_2 = Grupa_A.intersection(Grupa_B)

Roznica_zbiorow_1 = Grupa_A - Grupa_B
Roznica_zbiorow_2 = Grupa_A.difference(Grupa_B)

Roznica_symetryczna_1 = Grupa_A ^ Grupa_B
Roznica_symetryczna_2 = Grupa_A.symmetric_difference(Grupa_B)

answer_2 = f'''
Suma zbiorów:
    sposób a) {Suma_zbiorow_1},
    sposób b) {Suma_zbiorow_2}

Ilosczyn zbiorów:
    sposób a) {Wspolne_narzedzia_1},
    sposób b) {Wspolne_narzedzia_2}

Różnica zbiorów:
    sposób a) {Roznica_zbiorow_1},
    sposób b) {Roznica_zbiorow_2}

Różnica symetryczna zbiorów:
    sposób a) {Roznica_symetryczna_1},
    sposób b) {Roznica_symetryczna_2}

Czy zbiory są rozłączne? {Grupa_A.isdisjoint(Grupa_B)}
'''
print(answer_2)
# Out:
# Suma zbiorów:
#     sposób a) {'sql', 'ggplot2', 'tableau', 'r', 'python', 'numpy', 'pandas', 'dplyr'},
#     sposób b) {'sql', 'ggplot2', 'tableau', 'r', 'python', 'numpy', 'pandas', 'dplyr'}
#
# Ilosczyn zbiorów:
#     sposób a) {'sql', 'python'},
#     sposób b) {'sql', 'python'}
#
# Różnica zbiorów:
#     sposób a) {'tableau', 'numpy', 'pandas'},
#     sposób b) {'tableau', 'numpy', 'pandas'}
#
# Różnica symetryczna zbiorów:
#     sposób a) {'ggplot2', 'r', 'tableau', 'numpy', 'pandas', 'dplyr'},
#     sposób b) {'ggplot2', 'r', 'tableau', 'numpy', 'pandas', 'dplyr'}
#
# Czy zbiory są rozłączne? False

# %% [markdown]
# ***Zadanie 12. Pełne studium pojedynczego rekordu***
#
# Dany jest rekord datasetu Iris w postaci krotki:\
# rekord = ('setosa', 5.1, 3.5, 1.4, 0.2)\
# Pierwszy element to nazwa gatunku, kolejne cztery – kolejno sepal_length , sepal_width ,
# petal_length , petal_width .\
# Rozpakuj rekord do zmiennych: gatunek, sl, sw, pl, pw .\
# Utwórz słownik rekord_slownik , w którym kluczami są 'species' , 'sepal_length' ,\
# 'sepal_width' , 'petal_length' , 'petal_width' , a wartościami odpowiednie pola krotki.\
# Wypisz w formacie tabelarycznym:\
# species : setosa\
# sepal_length : 5.1\
# sepal_width : 3.5\
# petal_length : 1.4\
# petal_width : 0.2\
# (nazwa klucza wyrównana do lewej na 13 znakach, liczba do prawej na 5 z jednym miejscem po przecinku).\
# Używając sum i slajsu krotki, wypisz sumę wszystkich czterech cech liczbowych ( sum(rekord[1:]) ).

# %%
rekord = ('setosa', 5.1, 3.5, 1.4, 0.2)
gatunek = rekord[0]
sl = rekord[1]
sw = rekord[2]
pl = rekord[3]
pw = rekord[4]

keys = ('species' , 'sepal_length' ,'sepal_width' , 'petal_length' , 'petal_width')

slownik_gatunki = dict(zip(keys,rekord))

answer_3 = ''

for i in slownik_gatunki:
    answer_3+= f"""{i:<13}:{slownik_gatunki[i]:>5}\n"""

print(answer_3)
# Out:
# species      :setosa
# sepal_length :  5.1
# sepal_width  :  3.5
# petal_length :  1.4
# petal_width  :  0.2

# %% [markdown]
# *** ZADANIA DODATKOWE ***

# %% [markdown]
# ***Zadanie 10. Porównanie cech dwóch datasetów***
# Dwa datasety mają następujące cechy (kolumny):\
# dataset_a = {'wiek', 'plec', 'miasto', 'dochod', 'wyksztalcenie', 'stan_cywilny'}\
# dataset_b = {'wiek', 'plec', 'miasto', 'pensja', 'stanowisko', 'staz'}\
# Używając operacji na zbiorach wylicz i wypisz:\
# Cechy wspólne dla obu datasetów (iloczyn).\
# Cechy tylko w dataset_a (różnica a - b ).\
# Cechy tylko w dataset_b (różnica b - a ).\
# Wszystkie unikalne cechy (suma).\
# Cechy, które są tylko w jednym datasecie (różnica symetryczna).\
# Sprawdź, czy {'wiek', 'plec'} jest podzbiorem cech wspólnych ( .issubset() )\

# %%
dataset_a = {'wiek', 'plec', 'miasto', 'dochod', 'wyksztalcenie', 'stan_cywilny'}
dataset_b = {'wiek', 'plec', 'miasto', 'pensja', 'stanowisko', 'staz'}

iloczyn_setow = dataset_a | dataset_b
dataset_a_roznica = dataset_a-dataset_b
dataset_b_roznica = dataset_b-dataset_a
suma_datasetow = dataset_a & dataset_b
roznica_symetryczna = dataset_a ^ dataset_b

dataset_c = {'wiek', 'plec'}

answer_4 = dataset_c.issubset(suma_datasetow)
print(answer_4)
# Out:
# True

# %% [markdown]
# ***Zadanie 11. Mini-raport z zagnieżdżonego słownika***
#
# Dane:\
# raport = {
# 'Q1': {'przychod': 120_000, 'koszt': 80_000},\
# 'Q2': {'przychod': 145_000, 'koszt': 92_000},\
# 'Q3': {'przychod': 138_000, 'koszt': 88_000},\
# 'Q4': {'przychod': 167_000, 'koszt': 101_000}\
# }\
# - Wypisz w osobnych liniach przychód każdego kwartału (bez pętli – odwołuj się jawnie).\
# - Oblicz zysk każdego kwartału ( przychod - koszt ) i zapisz go jako nowy klucz zysk w słowniku\
# wewnętrznym.\
# - Wypisz tabelę w formacie: Q1 | 120000 | 80000 | 40000 (użyj :^6 lub :>8 do wyrównania).\
# - Zapisz listę wszystkich zysków i wypisz ich sumę, minimum, maksimum oraz średnią.\

# %%
raport = {
'Q1': {'przychod': 120_000, 'koszt': 80_000},
'Q2': {'przychod': 145_000, 'koszt': 92_000},
'Q3': {'przychod': 138_000, 'koszt': 88_000},
'Q4': {'przychod': 167_000, 'koszt': 101_000}
}

q1_przychod = raport['Q1']['przychod']
q2_przychod = raport['Q2']['przychod']
q3_przychod = raport['Q3']['przychod']
q4_przychod = raport['Q4']['przychod']

q1_zysk = q1_przychod - raport['Q1']['koszt']
q2_zysk = q2_przychod - raport['Q2']['koszt']
q3_zysk = q3_przychod - raport['Q3']['koszt']
q4_zysk = q4_przychod - raport['Q4']['koszt']

raport['Q1']['zysk'] = q1_zysk
raport['Q2']['zysk'] = q2_zysk
raport['Q3']['zysk'] = q3_zysk
raport['Q4']['zysk'] = q4_zysk

answer_11 = f'{'Kwartał':>8} | {'Przychód':>8} | {'Koszt':>8} | {'Zysk':>8}\n'


for i in raport:
    answer_11 += f'''{i:>8} | {raport[i]['przychod']:>8} | {raport[i]['koszt']:>8} | {raport[i]['zysk']:>8}\n'''
print(answer_11)

zyski = list(raport[i]['zysk'] for i in raport)

zyski_sum = sum(zyski)
zyski_min = min(zyski)
zyski_max = max(zyski)

zyski_average = zyski_sum / len(zyski)

print(f'''Spis zysków: {zyski},
suma: {zyski_sum},
wartość minimalna: {zyski_min},
wartość maksymalna: {zyski_max},
średnia wartość: {zyski_average}''')
# Out:
#  Kwartał | Przychód |    Koszt |     Zysk
#       Q1 |   120000 |    80000 |    40000
#       Q2 |   145000 |    92000 |    53000
#       Q3 |   138000 |    88000 |    50000
#       Q4 |   167000 |   101000 |    66000
#
# Spis zysków: [40000, 53000, 50000, 66000],
# suma: 209000,
# wartość minimalna: 40000,
# wartość maksymalna: 66000,
# średnia wartość: 52250.0

# %% [markdown]
# ***Zadanie 16. Analiza sprzedaży z kluczem-krotką***
# Dane:\
# sprzedaz = {\
# (2024, 'Q1'): 120_000,\
# (2024, 'Q2'): 145_000,\
# (2024, 'Q3'): 138_000,\
# (2024, 'Q4'): 167_000,\
# (2025, 'Q1'): 130_000,\
# (2025, 'Q2'): 155_000,\
# (2025, 'Q3'): 149_000\
# }\
# Wypisz całkowitą sprzedaż ( sum ).\
# Wypisz najwyższą i najniższą sprzedaż ( max , min ).\
# Użyj max(sprzedaz, key=sprzedaz.get) , aby znaleźć klucz (krotkę) z największą sprzedażą. Rozpakuj\
# go: rok_max, kw_max = ... . Wypisz: Najwyższa sprzedaż: 2024 Q4 – 167000 .\
# Użyj sorted(sprzedaz, key=sprzedaz.get, reverse=True) – zwróci klucze posortowane wg wartości\
# malejąco. Zapisz wynik do zmiennej i wypisz trzy najwyższe klucze (indeksy 0, 1, 2.\
# Zbuduj zbiór unikalnych lat ze wszystkich kluczy. Skorzystaj z jawnego zapisu – klucze masz wypisane\
# w literał słownika.\

# %%
sprzedaz = {
(2024, 'Q1'): 120_000,
(2024, 'Q2'): 145_000,
(2024, 'Q3'): 138_000,
(2024, 'Q4'): 167_000,
(2025, 'Q1'): 130_000,
(2025, 'Q2'): 155_000,
(2025, 'Q3'): 149_000
}

suma_sprzedazy = sum(sprzedaz.values())
min_sprzedazy = min(sprzedaz.values())
max_sprzedazy = max(sprzedaz.values())

krotka_max = max(sprzedaz, key= sprzedaz.get)

rok_max = krotka_max[0]
kw_max = krotka_max[1]

answer_16 = print(f'Najwyższa sprzedaż: {rok_max} {kw_max} -- {max_sprzedazy} ')

top_of_keys = sorted(sprzedaz, key= sprzedaz.get, reverse=True)

print(f'''Najlepszy kwartał to: {top_of_keys[0]}
Drugi najlepszy to: {top_of_keys[1]}
Trzeci najlepszy to: {top_of_keys[2]}''')

#Zbuduj zbiór unikalnych lat ze wszystkich kluczy. Skorzystaj z jawnego zapisu – klucze masz wypisane w literał słownika.

unikalne_lata = set({lata[0] for lata in sprzedaz.keys()})
# Out:
# Najwyższa sprzedaż: 2024 Q4 -- 167000
# Najlepszy kwartał to: (2024, 'Q4')
# Drugi najlepszy to: (2025, 'Q2')
# Trzeci najlepszy to: (2025, 'Q3')
# {2024, 2025}

# %% [markdown]
# ***Zadanie 18. Mały „JSON" – zagnieżdżona struktura***
#
# Zbuduj słownik projekt reprezentujący konfigurację eksperymentu:\
# projekt = {\
# 'nazwa': 'iris_classification',\
# 'wersja': (1, 2, 0), # krotka – wersja jako (major, minor, patch)\
# 'autorzy': {'Anna', 'Bartek', 'Cezary'}, # zbiór\
# 'dataset': {\
# 'nazwa': 'Iris',\
# 'shape': (150, 4),\
# 'klasy': ('setosa', 'versicolor', 'virginica')\
# },\
# 'hiperparametry': {\
# 'lr': 0.001,\
# 'batch_size': 64,\
# 'epochs': 50\
# }\
# }\
# Rozpakuj krotkę wersji: major, minor, patch = projekt['wersja'] . Wypisz w formacie: v1.2.0 .\
# Rozpakuj shape: n_rekordow, n_cech = projekt['dataset']['shape'] . Wypisz: Dataset Iris: 150 × 4 .\
# Dodaj nowego autora 'Dorota' do zbioru autorów ( .add() ).\
# Wypisz liczbę autorów i posortowaną alfabetycznie listę ( sorted ).\
# Zaktualizuj hiperparametry słownikiem {'dropout': 0.3, 'batch_size': 128} (wartość
# batch_size ma się nadpisać). Wypisz zaktualizowany słownik hiperparametrów.\
# Zmień klasy w dataset z krotki na zbiór ( projekt['dataset']['klasy'] = set(projekt['dataset']\
# ['klasy']) ) i sprawdź operatorem in , czy 'setosa' jest w zbiorze\

# %%
projekt = {
'nazwa': 'iris_classification',
'wersja': (1, 2, 0), # krotka – wersja jako (major, minor, patch)
'autorzy': {'Anna', 'Bartek', 'Cezary'}, # zbiór
'dataset': {
'nazwa': 'Iris',
'shape': (150, 4),
'klasy': ('setosa', 'versicolor', 'virginica')
},
'hiperparametry': {
'lr': 0.001,
'batch_size': 64,
'epochs': 50
}
}

#Rozpakuj krotkę wersji: major, minor, patch = projekt['wersja'] . Wypisz w formacie: v1.2.0 .

wersja = 'v'+'.'.join(str(i) for i in projekt['wersja'])

#Rozpakuj shape: n_rekordow, n_cech = projekt['dataset']['shape'] . Wypisz: Dataset Iris: 150 × 4

n_rekordow = projekt['dataset']['shape'][0]
n_cech = projekt['dataset']['shape'][1]
rozpakowany_shape = f'Dataset Iris {n_rekordow} x {n_cech}'

#Dodaj nowego autora 'Dorota' do zbioru autorów

projekt['autorzy'].add('Dorota')

#Wypisz liczbę autorów i posortowaną alfabetycznie listę

liczba_autorow = len(projekt['autorzy'])
autorzy_sorted = sorted(projekt['autorzy'])

#Zaktualizuj hiperparametry słownikiem {'dropout': 0.3, 'batch_size': 128} (wartość
#batch_size ma się nadpisać). Wypisz zaktualizowany słownik hiperparametrów.

slownik_18 = {'dropout': 0.3, 'batch_size': 128}
print(f'Przed zmianą: {projekt['hiperparametry']}')
projekt['hiperparametry'].update(slownik_18)
print(f'Po zmianie: {projekt['hiperparametry']}')

#Zmień klasy w dataset z krotki na zbiór ( projekt['dataset']['klasy'] = set(projekt['dataset']
#['klasy']) ) i sprawdź operatorem in , czy 'setosa' jest w zbiorze

print(f'Typ klasy przed zmianą: {type(projekt['dataset']['klasy'])}')
projekt['dataset']['klasy'] = set(projekt['dataset']['klasy'])
print(f'Typ klasy po zmianie: {type(projekt['dataset']['klasy'])}')

answer_18 = 'Tak' if 'setosa' in projekt['dataset']['klasy'] else 'Nie'

print(f'Czy setosa jest w zbiorze? {answer_18}')
# Out:
# Przed zmianą: {'lr': 0.001, 'batch_size': 64, 'epochs': 50}
# Po zmianie: {'lr': 0.001, 'batch_size': 128, 'epochs': 50, 'dropout': 0.3}
# Typ klasy przed zmianą: <class 'tuple'>
# Typ klasy po zmianie: <class 'set'>
# Czy setosa jest w zbiorze? Yes
